# %% [markdown]
# # Predicting Student Success Rate

# %% [markdown]
# Predicting student success rate is a data science project that aims to develop a machine learning model capable of forecasting students' academic performance. The project involves using historical student data, such as demographics, previous qualifications, attendance, and curricular performance, as features to predict the target variable, which is typically a measure of academic success (e.g., final grades, graduation status, or GPA).

# %% [markdown]
# # Importing Libraries :

# %% [markdown]
# These are just a few examples of popular Python libraries. You can import any other library using the same import statement followed by the library name or alias:
#
# NumPy: for numerical operations and array manipulation
#
# Pandas: for data manipulation and analysis
#
# Matplotlib: for creating visualizations
#
# Scikit-learn: for machine learning algorithms

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset :

# %% [markdown]
# The dataset provides comprehensive information about students' enrollment in various courses and includes data related to their personal characteristics, academic performance, and economic indicators. It encompasses fields such as marital status, application mode, and age at enrollment, shedding light on the diversity of students and their preferred application methods. Additionally, the dataset delves into the students' educational backgrounds, capturing details about their previous qualifications and the qualifications of their parents, which could potentially influence their academic journey. Furthermore, the dataset contains data on the students' attendance preferences, nationality, and special needs, allowing for a more nuanced understanding of the student population. Moreover, it includes valuable information on the curricular units in the first and second semesters, covering credit details, evaluations, approvals, and grades. Importantly, the dataset also incorporates economic indicators such as the unemployment rate, inflation rate, and GDP, which may offer insights into any correlations between economic conditions and academic outcomes. Lastly, the 'Target' column provides a focal point for analysis, indicating a variable of interest that researchers or analysts may seek to predict or understand better. Overall, this dataset presents a rich opportunity for exploring the complex interplay between student characteristics, academic performance, and economic factors

# %%
dataframe = pd.read_csv('dataset.csv')

# %% [markdown]
# # Exploratory Data Analysis :

# %% [markdown]
# Exploratory Data Analysis (EDA) is an essential process in data analysis that involves visually and statistically exploring a dataset to gain insights into its structure and relationships. It includes examining data distributions, correlations, and dependencies among variables. EDA helps identify outliers, missing values, and trends, leading to data preprocessing decisions and informing subsequent analysis steps. The process employs various data visualization techniques and is iterative, allowing for deeper understanding and generation of new research questions. Overall, EDA provides a solid foundation for meaningful data interpretation and effective decision-making.

# %%
dataframe.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nationality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
# 3                      23                      27                    6  ...
# 4                      22                      28                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    6
# 4                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate   GDP    Target
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
# 3            -0.8 -3.12  Graduate
# 4            -0.3  0.79  Graduate
#
# [5 rows x 35 columns]

# %%
dataframe.tail()
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nationality  \
# 4419                           1                       1            1
# 4420                           1                       1           19
# 4421                           1                       1            1
# 4422                           1                       1            1
# 4423                           1                       1            9
#
#       Mother's qualification  Father's qualification  Mother's occupation  \
# 4419                       1                       1                    6
# 4420                       1                       1                   10
# 4421                      22                      27                   10
# 4422                      22                      27                    8
# 4423                      23                      27                    6
#
#       ...  Curricular units 2nd sem (credited)  \
# 4419  ...                                    0
# 4420  ...                                    0
# 4421  ...                                    0
# 4422  ...                                    0
# 4423  ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 4419                                    6
# 4420                                    6
# 4421                                    8
# 4422                                    5
# 4423                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 4419                                       8
# 4420                                       6
# 4421                                       9
# 4422                                       6
# 4423                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 4419                                    5                         12.666667
# 4420                                    2                         11.000000
# 4421                                    1                         13.500000
# 4422                                    5                         12.000000
# 4423                                    6                         13.000000
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 4419                                               0               15.5
# 4420                                               0               11.1
# 4421                                               0               13.9
# 4422                                               0                9.4
# 4423                                               0               12.7
#
#       Inflation rate   GDP    Target
# 4419             2.8 -4.06  Graduate
# 4420             0.6  2.02   Dropout
# 4421            -0.3  0.79   Dropout
# 4422            -0.8 -3.12  Graduate
# 4423             3.7 -1.70  Graduate
#
# [5 rows x 35 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nationality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
#  9   Mother's occupation                             4424 non-null   int64
#  10  Father's occupation                             4424 non-null   int64
#  11  Displaced                                       4424 non-null   int64
#  12  Educational special needs                       4424 non-null   int64
#  13  Debtor                                          4424 non-null   int64
#  14  Tuition fees up to date                         4424 non-null   int64
#  15  Gender                                          4424 non-null   int64
#  16  Scholarship holder                              4424 non-null   int64
#  17  Age at enrollment                               4424 non-null   int64
#  18  International                                   4424 non-null   int64
#  19  Curricular units 1st sem (credited)             4424 non-null   int64
#  20  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  21  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  22  Curricular units 1st sem (approved)             4424 non-null   int64
#  23  Curricular units 1st sem (grade)                4424 non-null   float64
#  24  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  25  Curricular units 2nd sem (credited)             4424 non-null   int64
#  26  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  27  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  28  Curricular units 2nd sem (approved)             4424 non-null   int64
#  29  Curricular units 2nd sem (grade)                4424 non-null   float64
#  30  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  31  Unemployment rate                               4424 non-null   float64
#  32  Inflation rate                                  4424 non-null   float64
#  33  GDP                                             4424 non-null   float64
#  34  Target                                          4424 non-null   object
# dtypes: float64(5), int64(29), object(1)
# memory usage: 1.2+ MB

# %%
dataframe.isna().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nationality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# International                                     0
# Curricular units 1st sem (credited)               0
# Curricular units 1st sem (enrolled)               0
# Curricular units 1st sem (evaluations)            0
# Curricular units 1st sem (approved)               0
# Curricular units 1st sem (grade)                  0
# Curricular units 1st sem (without evaluations)    0
# Curricular units 2nd sem (credited)               0
# Curricular units 2nd sem (enrolled)               0
# Curricular units 2nd sem (evaluations)            0
# Curricular units 2nd sem (approved)               0
# Curricular units 2nd sem (grade)                  0
# Curricular units 2nd sem (without evaluations)    0
# Unemployment rate                                 0
# Inflation rate                                    0
# GDP                                               0
# Target                                            0
# dtype: int64

# %% [markdown]
# # Statical Info

# %% [markdown]
# Exploratory Data Analysis (EDA) involves a comprehensive examination of the dataset's statistical information to gain meaningful insights into its underlying patterns and characteristics. During this process, various key statistical measures are calculated and analyzed. Summary statistics, such as the mean, median, mode, standard deviation, minimum, maximum, and quartiles, offer an overview of the central tendencies and dispersion of numerical data. For categorical variables, count and frequency are determined to understand the distribution of each category. Correlation analysis reveals the strength and direction of linear relationships between numerical variables, while histograms and bar charts visually depict the distribution of data and frequency of categories, respectively.

# %%
dataframe.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571          6.886980           1.727848     9.899186
# std          0.605747          5.298964           1.313793     4.331792
# min          1.000000          1.000000           0.000000     1.000000
# 25%          1.000000          1.000000           1.000000     6.000000
# 50%          1.000000          8.000000           1.000000    10.000000
# 75%          1.000000         12.000000           2.000000    13.000000
# max          6.000000         18.000000           9.000000    17.000000
#
#        Daytime/evening attendance  Previous qualification  Nationality  \
# count                 4424.000000             4424.000000  4424.000000
# mean                     0.890823                2.531420     1.254521
# std                      0.311897                3.963707     1.748447
# min                      0.000000                1.000000     1.000000
# 25%                      1.000000                1.000000     1.000000
# 50%                      1.000000                1.000000     1.000000
# 75%                      1.000000                1.000000     1.000000
# max                      1.000000               17.000000    21.000000
#
#        Mother's qualification  Father's qualification  Mother's occupation  \
# count             4424.000000             4424.000000          4424.000000
# mean                12.322107               16.455244             7.317812
# std                  9.026251               11.044800             3.997828
# min                  1.000000                1.000000             1.000000
# 25%                  2.000000                3.000000             5.000000
# 50%                 13.000000               14.000000             6.000000
# 75%                 22.000000               27.000000            10.000000
# max                 29.000000               34.000000            32.000000
#
#        ...  Curricular units 1st sem (without evaluations)  \
# count  ...                                     4424.000000
# mean   ...                                        0.137658
# std    ...                                        0.690880
# min    ...                                        0.000000
# 25%    ...                                        0.000000
# 50%    ...                                        0.000000
# 75%    ...                                        0.000000
# max    ...                                       12.000000
#
#        Curricular units 2nd sem (credited)  \
# count                          4424.000000
# mean                              0.541817
# std                               1.918546
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              19.000000
#
#        Curricular units 2nd sem (enrolled)  \
# count                          4424.000000
# mean                              6.232143
# std                               2.195951
# min                               0.000000
# 25%                               5.000000
# 50%                               6.000000
# 75%                               7.000000
# max                              23.000000
#
#        Curricular units 2nd sem (evaluations)  \
# count                             4424.000000
# mean                                 8.063291
# std                                  3.947951
# min                                  0.000000
# 25%                                  6.000000
# 50%                                  8.000000
# 75%                                 10.000000
# max                                 33.000000
#
#        Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# count                          4424.000000                       4424.000000
# mean                              4.435805                         10.230206
# std                               3.014764                          5.210808
# min                               0.000000                          0.000000
# 25%                               2.000000                         10.750000
# 50%                               5.000000                         12.200000
# 75%                               6.000000                         13.333333
# max                              20.000000                         18.571429
#
#        Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# count                                     4424.000000        4424.000000
# mean                                         0.150316          11.566139
# std                                          0.753774           2.663850
# min                                          0.000000           7.600000
# 25%                                          0.000000           9.400000
# 50%                                          0.000000          11.100000
# 75%                                          0.000000          13.900000
# max                                         12.000000          16.200000
#
#        Inflation rate          GDP
# count     4424.000000  4424.000000
# mean         1.228029     0.001969
# std          1.382711     2.269935
# min         -0.800000    -4.060000
# 25%          0.300000    -1.700000
# 50%          1.400000     0.320000
# 75%          2.600000     1.790000
# max          3.700000     3.510000
#
# [8 rows x 34 columns]

# %%
dataframe.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nationality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Educational special needs', 'Debtor', 'Tuition fees up to date',
#        'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
#        'Inflation rate', 'GDP', 'Target'],
#       dtype='object')

# %%
dataframe = dataframe[dataframe .Target!='Enrolled']

# %%
dataframe.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nationality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Educational special needs', 'Debtor', 'Tuition fees up to date',
#        'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
#        'Inflation rate', 'GDP', 'Target'],
#       dtype='object')

# %% [markdown]
# # Encoding :

# %% [markdown]
# Encoding refers to the process of converting data from one format or representation to another. In the context of data analysis and machine learning, encoding is often used to transform categorical or text data into numerical form, which can be more easily processed and utilized by algorithms.

# %% [markdown]
# Label Encoding: In label encoding, each unique category in a categorical variable is assigned an integer label. For example, if we have categories like "Red," "Green," and "Blue," they could be encoded as 0, 1, and 2, respectively. However, caution should be exercised when using label encoding for ordinal data, as the numerical representation may introduce an unintended ordinal relationship.

# %%
dataframe['Target'].value_counts()
# Out:
# Graduate    2209
# Dropout     1421
# Name: Target, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
dataframe['Target'] = encoder.fit_transform(dataframe['Target'])

# %%
dataframe['Target'].value_counts()
# Out:
# 1    2209
# 0    1421
# Name: Target, dtype: int64

# %% [markdown]
# # Distribution Table of Graduate and Non Graduate

# %%
dataframe['Target'].value_counts().plot(kind = 'bar', 
                                        title = 'Distrbution of Target Value', 
                                        cmap = 'plasma')
# Out:
# <Axes: title={'center': 'Distrbution of Target Value'}>

# %% [markdown]
# # Correlation Matrix :

# %% [markdown]
# A correlation matrix is a table that shows the pairwise correlations between variables in a dataset. Each cell in the table represents the correlation between two variables, and the strength and direction of the correlation is indicated by the color and magnitude of the cell.
#
# Correlation matrices are commonly used in data analysis to identify relationships between variables and to help understand the structure of the data. The values in the correlation matrix range from -1 to 1, with -1 indicating a perfect negative correlation, 1 indicating a perfect positive correlation, and 0 indicating no correlation.

# %%
corr_matrix = dataframe.corr()

# %%
corr_matrix
# Out:
#                                                 Marital status  \
# Marital status                                        1.000000
# Application mode                                      0.235554
# Application order                                    -0.130370
# Course                                                0.003120
# Daytime/evening attendance                           -0.265823
# Previous qualification                                0.134920
# Nationality                                          -0.020139
# Mother's qualification                                0.177000
# Father's qualification                                0.122920
# Mother's occupation                                   0.070876
# Father's occupation                                   0.029487
# Displaced                                            -0.240544
# Educational special needs                            -0.027434
# Debtor                                                0.039470
# Tuition fees up to date                              -0.096920
# Gender                                               -0.001124
# Scholarship holder                                   -0.069684
# Age at enrollment                                     0.522359
# International                                        -0.026153
# Curricular units 1st sem (credited)                   0.066666
# Curricular units 1st sem (enrolled)                   0.058094
# Curricular units 1st sem (evaluations)                0.059191
# Curricular units 1st sem (approved)                  -0.037691
# Curricular units 1st sem (grade)                     -0.069442
# Curricular units 1st sem (without evaluations)        0.041535
# Curricular units 2nd sem (credited)                   0.067508
# Curricular units 2nd sem (enrolled)                   0.041256
# Curricular units 2nd sem (evaluations)                0.030786
# Curricular units 2nd sem (approved)                  -0.058400
# Curricular units 2nd sem (grade)                     -0.079536
# Curricular units 2nd sem (without evaluations)        0.025193
# Unemployment rate                                    -0.018959
# Inflation rate                                        0.011932
# GDP                                                  -0.028391
# Target                                               -0.100479
#
#                                                 Application mode  \
# Marital status                                          0.235554
# Application mode                                        1.000000
# Application order                                      -0.246369
# Course                                                 -0.083865
# Daytime/evening attendance                             -0.276859
# Previous qualification                                  0.429339
# Nationality                                            -0.009654
# Mother's qualification                                  0.096560
# Father's qualification                                  0.086848
# Mother's occupation                                     0.014639
# Father's occupation                                    -0.014781
# Displaced                                              -0.270626
# Educational special needs                              -0.023816
# Debtor                                                  0.111712
# Tuition fees up to date                                -0.142187
# Gender                                                  0.170454
# Scholarship holder                                     -0.163377
# Age at enrollment                                       0.465425
# International                                          -0.001957
# Curricular units 1st sem (credited)                     0.240052
# Curricular units 1st sem (enrolled)                     0.164988
# Curricular units 1st sem (evaluations)                  0.214080
# Curricular units 1st sem (approved)                    -0.029964
# Curricular units 1st sem (grade)                       -0.120509
# Curricular units 1st sem (without evaluations)          0.045942
# Curricular units 2nd sem (credited)                     0.235376
# Curricular units 2nd sem (enrolled)                     0.129428
# Curricular units 2nd sem (evaluations)                  0.160493
# Curricular units 2nd sem (approved)                    -0.076839
# Curricular units 2nd sem (grade)                       -0.124287
# Curricular units 2nd sem (without evaluations)          0.052751
# Unemployment rate                                       0.075779
# Inflation rate                                         -0.027668
# GDP                                                    -0.014998
# Target                                                 -0.233888
#
#                                                 Application order    Course  \
# Marital status                                          -0.130370  0.003120
# Application mode                                        -0.246369 -0.083865
# Application order                                        1.000000  0.124436
# Course                                                   0.124436  1.000000
# Daytime/evening attendance                               0.165494 -0.033420
# Previous qualification                                  -0.204205 -0.156097
# Nationality                                             -0.033548  0.002081
# Mother's qualification                                  -0.055105  0.039210
# Father's qualification                                  -0.054670  0.031936
# Mother's occupation                                     -0.036993  0.015836
# Father's occupation                                     -0.027257  0.001650
# Displaced                                                0.345791  0.011541
# Educational special needs                                0.025712 -0.008769
# Debtor                                                  -0.066227 -0.040454
# Tuition fees up to date                                  0.061610  0.025475
# Gender                                                  -0.106059 -0.092122
# Scholarship holder                                       0.072899  0.051866
# Age at enrollment                                       -0.281641 -0.055373
# International                                           -0.030576  0.006487
# Curricular units 1st sem (credited)                     -0.133504 -0.136291
# Curricular units 1st sem (enrolled)                     -0.015182  0.110282
# Curricular units 1st sem (evaluations)                  -0.086004  0.018684
# Curricular units 1st sem (approved)                      0.038274  0.074528
# Curricular units 1st sem (grade)                         0.060776  0.174542
# Curricular units 1st sem (without evaluations)          -0.038958 -0.064952
# Curricular units 2nd sem (credited)                     -0.127599 -0.122366
# Curricular units 2nd sem (enrolled)                      0.033125  0.184817
# Curricular units 2nd sem (evaluations)                  -0.042519  0.063649
# Curricular units 2nd sem (approved)                      0.072595  0.104974
# Curricular units 2nd sem (grade)                         0.059817  0.171483
# Curricular units 2nd sem (without evaluations)          -0.026822 -0.015006
# Unemployment rate                                       -0.099767 -0.053998
# Inflation rate                                          -0.004228  0.038674
# GDP                                                      0.033031  0.005770
# Target                                                   0.094355  0.006814
#
#                                                 Daytime/evening attendance  \
# Marital status                                                   -0.265823
# Application mode                                                 -0.276859
# Application order                                                 0.165494
# Course                                                           -0.033420
# Daytime/evening attendance                                        1.000000
# Previous qualification                                           -0.120619
# Nationality                                                       0.032272
# Mother's qualification                                           -0.179286
# Father's qualification                                           -0.133407
# Mother's occupation                                              -0.035792
# Father's occupation                                              -0.002980
# Displaced                                                         0.243653
# Educational special needs                                         0.029207
# Debtor                                                            0.003900
# Tuition fees up to date                                           0.052186
# Gender                                                           -0.030507
# Scholarship holder                                                0.110240
# Age at enrollment                                                -0.453741
# International                                                     0.032494
# Curricular units 1st sem (credited)                              -0.124038
# Curricular units 1st sem (enrolled)                              -0.041503
# Curricular units 1st sem (evaluations)                           -0.048432
# Curricular units 1st sem (approved)                               0.028265
# Curricular units 1st sem (grade)                                  0.073270
# Curricular units 1st sem (without evaluations)                    0.039307
# Curricular units 2nd sem (credited)                              -0.105494
# Curricular units 2nd sem (enrolled)                               0.006915
# Curricular units 2nd sem (evaluations)                            0.009977
# Curricular units 2nd sem (approved)                               0.054211
# Curricular units 2nd sem (grade)                                  0.058371
# Curricular units 2nd sem (without evaluations)                   -0.010504
# Unemployment rate                                                 0.067192
# Inflation rate                                                   -0.017326
# GDP                                                               0.005007
# Target                                                            0.084496
#
#                                                 Previous qualification  \
# Marital status                                                0.134920
# Application mode                                              0.429339
# Application order                                            -0.204205
# Course                                                       -0.156097
# Daytime/evening attendance                                   -0.120619
# Previous qualification                                        1.000000
# Nationality                                                  -0.035397
# Mother's qualification                                        0.011777
# Father's qualification                                        0.022088
# Mother's occupation                                           0.001426
# Father's occupation                                           0.010741
# Displaced                                                    -0.165781
# Educational special needs                                    -0.008083
# Debtor                                                        0.122667
# Tuition fees up to date                                      -0.095072
# Gender                                                        0.107378
# Scholarship holder                                           -0.090529
# Age at enrollment                                             0.268435
# International                                                -0.031867
# Curricular units 1st sem (credited)                           0.159908
# Curricular units 1st sem (enrolled)                           0.078540
# Curricular units 1st sem (evaluations)                        0.126542
# Curricular units 1st sem (approved)                          -0.015991
# Curricular units 1st sem (grade)                             -0.048686
# Curricular units 1st sem (without evaluations)                0.039461
# Curricular units 2nd sem (credited)                           0.139557
# Curricular units 2nd sem (enrolled)                           0.052077
# Curricular units 2nd sem (evaluations)                        0.084018
# Curricular units 2nd sem (approved)                          -0.046298
# Curricular units 2nd sem (grade)                             -0.051467
# Curricular units 2nd sem (without evaluations)                0.045677
# Unemployment rate                                             0.086015
# Inflation rate                                               -0.059770
# GDP                                                           0.058446
# Target                                                       -0.102795
#
#                                                 Nationality  \
# Marital status                                    -0.020139
# Application mode                                  -0.009654
# Application order                                 -0.033548
# Course                                             0.002081
# Daytime/evening attendance                         0.032272
# Previous qualification                            -0.035397
# Nationality                                        1.000000
# Mother's qualification                            -0.029701
# Father's qualification                            -0.075359
# Mother's occupation                                0.023369
# Father's occupation                                0.016858
# Displaced                                         -0.002003
# Educational special needs                          0.002022
# Debtor                                             0.066785
# Tuition fees up to date                           -0.053855
# Gender                                            -0.031648
# Scholarship holder                                -0.010955
# Age at enrollment                                 -0.009002
# International                                      0.915343
# Curricular units 1st sem (credited)                0.008520
# Curricular units 1st sem (enrolled)               -0.014812
# Curricular units 1st sem (evaluations)            -0.003763
# Curricular units 1st sem (approved)                0.001177
# Curricular units 1st sem (grade)                  -0.000342
# Curricular units 1st sem (without evaluations)     0.007050
# Curricular units 2nd sem (credited)                0.002243
# Curricular units 2nd sem (enrolled)               -0.028418
# Curricular units 2nd sem (evaluations)            -0.025326
# Curricular units 2nd sem (approved)               -0.017487
# Curricular units 2nd sem (grade)                  -0.010592
# Curricular units 2nd sem (without evaluations)    -0.012158
# Unemployment rate                                 -0.002953
# Inflation rate                                    -0.010158
# GDP                                                0.028410
# Target                                            -0.003823
#
#                                                 Mother's qualification  \
# Marital status                                                0.177000
# Application mode                                              0.096560
# Application order                                            -0.055105
# Course                                                        0.039210
# Daytime/evening attendance                                   -0.179286
# Previous qualification                                        0.011777
# Nationality                                                  -0.029701
# Mother's qualification                                        1.000000
# Father's qualification                                        0.532757
# Mother's occupation                                           0.309000
# Father's occupation                                           0.134823
# Displaced                                                    -0.071407
# Educational special needs                                    -0.010358
# Debtor                                                        0.011009
# Tuition fees up to date                                      -0.027624
# Gender                                                       -0.046287
# Scholarship holder                                            0.029713
# Age at enrollment                                             0.277025
# International                                                -0.019923
# Curricular units 1st sem (credited)                           0.042615
# Curricular units 1st sem (enrolled)                           0.048221
# Curricular units 1st sem (evaluations)                        0.046130
# Curricular units 1st sem (approved)                          -0.017416
# Curricular units 1st sem (grade)                             -0.041897
# Curricular units 1st sem (without evaluations)                0.013946
# Curricular units 2nd sem (credited)                           0.035655
# Curricular units 2nd sem (enrolled)                           0.030811
# Curricular units 2nd sem (evaluations)                        0.030954
# Curricular units 2nd sem (approved)                          -0.024289
# Curricular units 2nd sem (grade)                             -0.031406
# Curricular units 2nd sem (without evaluations)                0.027816
# Unemployment rate                                            -0.113616
# Inflation rate                                                0.055484
# GDP                                                          -0.071692
# Target                                                       -0.048459
#
#                                                 Father's qualification  \
# Marital status                                                0.122920
# Application mode                                              0.086848
# Application order                                            -0.054670
# Course                                                        0.031936
# Daytime/evening attendance                                   -0.133407
# Previous qualification                                        0.022088
# Nationality                                                  -0.075359
# Mother's qualification                                        0.532757
# Father's qualification                                        1.000000
# Mother's occupation                                           0.222273
# Father's occupation                                           0.193711
# Displaced                                                    -0.065461
# Educational special needs                                     0.004911
# Debtor                                                       -0.005532
# Tuition fees up to date                                      -0.023587
# Gender                                                       -0.058607
# Scholarship holder                                            0.093935
# Age at enrollment                                             0.191500
# International                                                -0.069226
# Curricular units 1st sem (credited)                           0.044481
# Curricular units 1st sem (enrolled)                           0.043478
# Curricular units 1st sem (evaluations)                        0.042950
# Curricular units 1st sem (approved)                           0.009680
# Curricular units 1st sem (grade)                             -0.005168
# Curricular units 1st sem (without evaluations)               -0.007145
# Curricular units 2nd sem (credited)                           0.045833
# Curricular units 2nd sem (enrolled)                           0.028976
# Curricular units 2nd sem (evaluations)                        0.014340
# Curricular units 2nd sem (approved)                           0.002196
# Curricular units 2nd sem (grade)                             -0.007022
# Curricular units 2nd sem (without evaluations)                0.002835
# Unemployment rate                                            -0.072628
# Inflation rate                                                0.061684
# GDP                                                          -0.058259
# Target                                                       -0.003850
#
#                                                 Mother's occupation  ...  \
# Marital status                                             0.070876  ...
# Application mode                                           0.014639  ...
# Application order                                         -0.036993  ...
# Course                                                     0.015836  ...
# Daytime/evening attendance                                -0.035792  ...
# Previous qualification                                     0.001426  ...
# Nationality                                                0.023369  ...
# Mother's qualification                                     0.309000  ...
# Father's qualification                                     0.222273  ...
# Mother's occupation                                        1.000000  ...
# Father's occupation                                        0.693807  ...
# Displaced                                                 -0.042925  ...
# Educational special needs                                  0.001767  ...
# Debtor                                                     0.093864  ...
# Tuition fees up to date                                   -0.017352  ...
# Gender                                                    -0.034881  ...
# Scholarship holder                                         0.121071  ...
# Age at enrollment                                          0.078605  ...
# International                                              0.012063  ...
# Curricular units 1st sem (credited)                       -0.001322  ...
# Curricular units 1st sem (enrolled)                        0.005122  ...
# Curricular units 1st sem (evaluations)                    -0.005374  ...
# Curricular units 1st sem (approved)                        0.019219  ...
# Curricular units 1st sem (grade)                           0.014713  ...
# Curricular units 1st sem (without evaluations)            -0.013753  ...
# Curricular units 2nd sem (credited)                       -0.003886  ...
# Curricular units 2nd sem (enrolled)                        0.001080  ...
# Curricular units 2nd sem (evaluations)                    -0.006691  ...
# Curricular units 2nd sem (approved)                        0.030936  ...
# Curricular units 2nd sem (grade)                           0.041212  ...
# Curricular units 2nd sem (without evaluations)            -0.001678  ...
# Unemployment rate                                          0.009914  ...
# Inflation rate                                             0.030070  ...
# GDP                                                        0.070732  ...
# Target                                                     0.064195  ...
#
#                                                 Curricular units 2nd sem (credited)  \
# Marital status                                                             0.067508
# Application mode                                                           0.235376
# Application order                                                         -0.127599
# Course                                                                    -0.122366
# Daytime/evening attendance                                                -0.105494
# Previous qualification                                                     0.139557
# Nationality                                                                0.002243
# Mother's qualification                                                     0.035655
# Father's qualification                                                     0.045833
# Mother's occupation                                                       -0.003886
# Father's occupation                                                       -0.017998
# Displaced                                                                 -0.096240
# Educational special needs                                                 -0.019928
# Debtor                                                                     0.007597
# Tuition fees up to date                                                    0.020306
# Gender                                                                     0.023027
# Scholarship holder                                                        -0.079378
# Age at enrollment                                                          0.196485
# International                                                              0.006237
# Curricular units 1st sem (credited)                                        0.947093
# Curricular units 1st sem (enrolled)                                        0.763276
# Curricular units 1st sem (evaluations)                                     0.546980
# Curricular units 1st sem (approved)                                        0.615834
# Curricular units 1st sem (grade)                                           0.120199
# Curricular units 1st sem (without evaluations)                             0.144378
# Curricular units 2nd sem (credited)                                        1.000000
# Curricular units 2nd sem (enrolled)                                        0.683086
# Curricular units 2nd sem (evaluations)                                     0.453716
# Curricular units 2nd sem (approved)                                        0.522684
# Curricular units 2nd sem (grade)                                           0.140181
# Curricular units 2nd sem (without evaluations)                             0.084506
# Unemployment rate                                                          0.013466
# Inflation rate                                                             0.019395
# GDP                                                                       -0.038570
# Target                                                                     0.052402
#
#                                                 Curricular units 2nd sem (enrolled)  \
# Marital status                                                             0.041256
# Application mode                                                           0.129428
# Application order                                                          0.033125
# Course                                                                     0.184817
# Daytime/evening attendance                                                 0.006915
# Previous qualification                                                     0.052077
# Nationality                                                               -0.028418
# Mother's qualification                                                     0.030811
# Father's qualification                                                     0.028976
# Mother's occupation                                                        0.001080
# Father's occupation                                                       -0.009356
# Displaced                                                                 -0.046431
# Educational special needs                                                 -0.032488
# Debtor                                                                    -0.050772
# Tuition fees up to date                                                    0.103347
# Gender                                                                    -0.126659
# Scholarship holder                                                         0.024982
# Age at enrollment                                                          0.071177
# International                                                             -0.019606
# Curricular units 1st sem (credited)                                        0.650707
# Curricular units 1st sem (enrolled)                                        0.941286
# Curricular units 1st sem (evaluations)                                     0.625967
# Curricular units 1st sem (approved)                                        0.737375
# Curricular units 1st sem (grade)                                           0.407084
# Curricular units 1st sem (without evaluations)                             0.123588
# Curricular units 2nd sem (credited)                                        0.683086
# Curricular units 2nd sem (enrolled)                                        1.000000
# Curricular units 2nd sem (evaluations)                                     0.625080
# Curricular units 2nd sem (approved)                                        0.704445
# Curricular units 2nd sem (grade)                                           0.400773
# Curricular units 2nd sem (without evaluations)                             0.070363
# Unemployment rate                                                          0.066219
# Inflation rate                                                             0.028390
# GDP                                                                       -0.026076
# Target                                                                     0.182897
#
#                                                 Curricular units 2nd sem (evaluations)  \
# Marital status                                                                0.030786
# Application mode                                                              0.160493
# Application order                                                            -0.042519
# Course                                                                        0.063649
# Daytime/evening attendance                                                    0.009977
# Previous qualification                                                        0.084018
# Nationality                                                                  -0.025326
# Mother's qualification                                                        0.030954
# Father's qualification                                                        0.014340
# Mother's occupation                                                          -0.006691
# Father's occupation                                                          -0.028205
# Displaced                                                                    -0.035874
# Educational special needs                                                    -0.022319
# Debtor                                                                        0.014412
# Tuition fees up to date                                                       0.055691
# Gender                                                                       -0.048000
# Scholarship holder                                                            0.005903
# Age at enrollment                                                             0.059554
# International                                                                -0.013539
# Curricular units 1st sem (credited)                                           0.448136
# Curricular units 1st sem (enrolled)                                           0.618506
# Curricular units 1st sem (evaluations)                                        0.790616
# Curricular units 1st sem (approved)                                           0.579089
# Curricular units 1st sem (grade)                                              0.503365
# Curricular units 1st sem (without evaluations)                                0.170004
# Curricular units 2nd sem (credited)                                           0.453716
# Curricular units 2nd sem (enrolled)                                           0.625080
# Curricular units 2nd sem (evaluations)                                        1.000000
# Curricular units 2nd sem (approved)                                           0.508968
# Curricular units 2nd sem (grade)                                              0.463194
# Curricular units 2nd sem (without evaluations)                                0.166443
# Unemployment rate                                                             0.055229
# Inflation rate                                                               -0.001422
# GDP                                                                          -0.021846
# Target                                                                        0.119239
#
#                                                 Curricular units 2nd sem (approved)  \
# Marital status                                                            -0.058400
# Application mode                                                          -0.076839
# Application order                                                          0.072595
# Course                                                                     0.104974
# Daytime/evening attendance                                                 0.054211
# Previous qualification                                                    -0.046298
# Nationality                                                               -0.017487
# Mother's qualification                                                    -0.024289
# Father's qualification                                                     0.002196
# Mother's occupation                                                        0.030936
# Father's occupation                                                        0.032742
# Displaced                                                                  0.076466
# Educational special needs                                                 -0.018142
# Debtor                                                                    -0.166305
# Tuition fees up to date                                                    0.329017
# Gender                                                                    -0.234663
# Scholarship holder                                                         0.214997
# Age at enrollment                                                         -0.147668
# International                                                             -0.010648
# Curricular units 1st sem (credited)                                        0.495762
# Curricular units 1st sem (enrolled)                                        0.674880
# Curricular units 1st sem (evaluations)                                     0.466744
# Curricular units 1st sem (approved)                                        0.916334
# Curricular units 1st sem (grade)                                           0.691907
# Curricular units 1st sem (without evaluations)                             0.001458
# Curricular units 2nd sem (credited)                                        0.522684
# Curricular units 2nd sem (enrolled)                                        0.704445
# Curricular units 2nd sem (evaluations)                                     0.508968
# Curricular units 2nd sem (approved)                                        1.000000
# Curricular units 2nd sem (grade)                                           0.786838
# Curricular units 2nd sem (without evaluations)                            -0.052389
# Unemployment rate                                                          0.040061
# Inflation rate                                                            -0.026751
# GDP                                                                        0.014514
# Target                                                                     0.653995
#
#                                                 Curricular units 2nd sem (grade)  \
# Marital status                                                         -0.079536
# Application mode                                                       -0.124287
# Application order                                                       0.059817
# Course                                                                  0.171483
# Daytime/evening attendance                                              0.058371
# Previous qualification                                                 -0.051467
# Nationality                                                            -0.010592
# Mother's qualification                                                 -0.031406
# Father's qualification                                                 -0.007022
# Mother's occupation                                                     0.041212
# Father's occupation                                                     0.041246
# Displaced                                                               0.084463
# Educational special needs                                              -0.014808
# Debtor                                                                 -0.146603
# Tuition fees up to date                                                 0.318721
# Gender                                                                 -0.219696
# Scholarship holder                                                      0.212342
# Age at enrollment                                                      -0.194145
# International                                                          -0.003066
# Curricular units 1st sem (credited)                                     0.142343
# Curricular units 1st sem (enrolled)                                     0.366015
# Curricular units 1st sem (evaluations)                                  0.353550
# Curricular units 1st sem (approved)                                     0.709368
# Curricular units 1st sem (grade)                                        0.845864
# Curricular units 1st sem (without evaluations)                         -0.068725
# Curricular units 2nd sem (credited)                                     0.140181
# Curricular units 2nd sem (enrolled)                                     0.400773
# Curricular units 2nd sem (evaluations)                                  0.463194
# Curricular units 2nd sem (approved)                                     0.786838
# Curricular units 2nd sem (grade)                                        1.000000
# Curricular units 2nd sem (without evaluations)                         -0.079508
# Unemployment rate                                                       0.000261
# Inflation rate                                                         -0.042639
# GDP                                                                     0.066077
# Target                                                                  0.605350
#
#                                                 Curricular units 2nd sem (without evaluations)  \
# Marital status                                                                        0.025193
# Application mode                                                                      0.052751
# Application order                                                                    -0.026822
# Course                                                                               -0.015006
# Daytime/evening attendance                                                           -0.010504
# Previous qualification                                                                0.045677
# Nationality                                                                          -0.012158
# Mother's qualification                                                                0.027816
# Father's qualification                                                                0.002835
# Mother's occupation                                                                  -0.001678
# Father's occupation                                                                  -0.047528
# Displaced                                                                            -0.041696
# Educational special needs                                                            -0.013011
# Debtor                                                                                0.069970
# Tuition fees up to date                                                              -0.095139
# Gender                                                                                0.057755
# Scholarship holder                                                                   -0.060597
# Age at enrollment                                                                     0.080135
# International                                                                        -0.012660
# Curricular units 1st sem (credited)                                                   0.069001
# Curricular units 1st sem (enrolled)                                                   0.075677
# Curricular units 1st sem (evaluations)                                                0.158399
# Curricular units 1st sem (approved)                                                  -0.038974
# Curricular units 1st sem (grade)                                                     -0.055861
# Curricular units 1st sem (without evaluations)                                        0.601573
# Curricular units 2nd sem (credited)                                                   0.084506
# Curricular units 2nd sem (enrolled)                                                   0.070363
# Curricular units 2nd sem (evaluations)                                                0.166443
# Curricular units 2nd sem (approved)                                                  -0.052389
# Curricular units 2nd sem (grade)                                                     -0.079508
# Curricular units 2nd sem (without evaluations)                                        1.000000
# Unemployment rate                                                                     0.004067
# Inflation rate                                                                       -0.030552
# GDP                                                                                  -0.079857
# Target                                                                               -0.102687
#
#                                                 Unemployment rate  \
# Marital status                                          -0.018959
# Application mode                                         0.075779
# Application order                                       -0.099767
# Course                                                  -0.053998
# Daytime/evening attendance                               0.067192
# Previous qualification                                   0.086015
# Nationality                                             -0.002953
# Mother's qualification                                  -0.113616
# Father's qualification                                  -0.072628
# Mother's occupation                                      0.009914
# Father's occupation                                     -0.014017
# Displaced                                               -0.120367
# Educational special needs                                0.043913
# Debtor                                                   0.042792
# Tuition fees up to date                                  0.009479
# Gender                                                   0.030020
# Scholarship holder                                       0.066351
# Age at enrollment                                        0.027129
# International                                           -0.008089
# Curricular units 1st sem (credited)                      0.013313
# Curricular units 1st sem (enrolled)                      0.039788
# Curricular units 1st sem (evaluations)                   0.067011
# Curricular units 1st sem (approved)                      0.042251
# Curricular units 1st sem (grade)                         0.010272
# Curricular units 1st sem (without evaluations)          -0.035046
# Curricular units 2nd sem (credited)                      0.013466
# Curricular units 2nd sem (enrolled)                      0.066219
# Curricular units 2nd sem (evaluations)                   0.055229
# Curricular units 2nd sem (approved)                      0.040061
# Curricular units 2nd sem (grade)                         0.000261
# Curricular units 2nd sem (without evaluations)           0.004067
# Unemployment rate                                        1.000000
# Inflation rate                                          -0.029666
# GDP                                                     -0.341742
# Target                                                   0.004198
#
#                                                 Inflation rate       GDP  \
# Marital status                                        0.011932 -0.028391
# Application mode                                     -0.027668 -0.014998
# Application order                                    -0.004228  0.033031
# Course                                                0.038674  0.005770
# Daytime/evening attendance                           -0.017326  0.005007
# Previous qualification                               -0.059770  0.058446
# Nationality                                          -0.010158  0.028410
# Mother's qualification                                0.055484 -0.071692
# Father's qualification                                0.061684 -0.058259
# Mother's occupation                                   0.030070  0.070732
# Father's occupation                                   0.028419  0.098918
# Displaced                                            -0.009026  0.064923
# Educational special needs                             0.004452  0.010978
# Debtor                                               -0.019516  0.040475
# Tuition fees up to date                              -0.011067  0.027771
# Gender                                               -0.004466 -0.021931
# Scholarship holder                                   -0.044622  0.037842
# Age at enrollment                                     0.030085 -0.069184
# International                                        -0.005909  0.023997
# Curricular units 1st sem (credited)                   0.030038 -0.044169
# Curricular units 1st sem (enrolled)                   0.051167 -0.047367
# Curricular units 1st sem (evaluations)                0.008854 -0.111698
# Curricular units 1st sem (approved)                  -0.003858 -0.000120
# Curricular units 1st sem (grade)                     -0.029068  0.054168
# Curricular units 1st sem (without evaluations)       -0.037235 -0.130766
# Curricular units 2nd sem (credited)                   0.019395 -0.038570
# Curricular units 2nd sem (enrolled)                   0.028390 -0.026076
# Curricular units 2nd sem (evaluations)               -0.001422 -0.021846
# Curricular units 2nd sem (approved)                  -0.026751  0.014514
# Curricular units 2nd sem (grade)                     -0.042639  0.066077
# Curricular units 2nd sem (without evaluations)       -0.030552 -0.079857
# Unemployment rate                                    -0.029666 -0.341742
# Inflation rate                                        1.000000 -0.125789
# GDP                                                  -0.125789  1.000000
# Target                                               -0.030326  0.050260
#
#                                                   Target
# Marital status                                 -0.100479
# Application mode                               -0.233888
# Application order                               0.094355
# Course                                          0.006814
# Daytime/evening attendance                      0.084496
# Previous qualification                         -0.102795
# Nationality                                    -0.003823
# Mother's qualification                         -0.048459
# Father's qualification                         -0.003850
# Mother's occupation                             0.064195
# Father's occupation                             0.073238
# Displaced                                       0.126113
# Educational special needs                      -0.007254
# Debtor                                         -0.267207
# Tuition fees up to date                         0.442138
# Gender                                         -0.251955
# Scholarship holder                              0.313018
# Age at enrollment                              -0.267229
# International                                   0.006181
# Curricular units 1st sem (credited)             0.046900
# Curricular units 1st sem (enrolled)             0.161074
# Curricular units 1st sem (evaluations)          0.059786
# Curricular units 1st sem (approved)             0.554881
# Curricular units 1st sem (grade)                0.519927
# Curricular units 1st sem (without evaluations) -0.074642
# Curricular units 2nd sem (credited)             0.052402
# Curricular units 2nd sem (enrolled)             0.182897
# Curricular units 2nd sem (evaluations)          0.119239
# Curricular units 2nd sem (approved)             0.653995
# Curricular units 2nd sem (grade)                0.605350
# Curricular units 2nd sem (without evaluations) -0.102687
# Unemployment rate                               0.004198
# Inflation rate                                 -0.030326
# GDP                                             0.050260
# Target                                          1.000000
#
# [35 rows x 35 columns]

# %%
plt.figure(figsize = (25, 25))
sns.heatmap(corr_matrix, 
            annot = True, 
            cmap = 'inferno')
# Out:
# <Axes: >

# %% [markdown]
# # Feature Selection :

# %% [markdown]
# Feature selection is an essential process in data analysis and machine learning, focused on choosing the most relevant and informative subset of features from the original dataset. The primary goal is to improve the model's performance, reduce complexity, and enhance interpretability. By eliminating irrelevant, redundant, or noisy features, feature selection helps prevent overfitting and enables the model to generalize better to new data. This, in turn, reduces computation time and memory requirements during model training and evaluation. Various techniques can be employed for feature selection, including filter methods that rank features based on statistical measures, wrapper methods that utilize the model's predictive performance, and embedded methods that incorporate feature selection within the model training process. Additionally, dimensionality reduction techniques like PCA offer an alternative approach by projecting the data onto a lower-dimensional space. Ultimately, selecting the right features is critical to producing more efficient and accurate models, facilitating data-driven insights and decision-making with enhanced clarity and efficiency.

# %%
dataframe.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nationality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Educational special needs', 'Debtor', 'Tuition fees up to date',
#        'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
#        'Inflation rate', 'GDP', 'Target'],
#       dtype='object')

# %%
dataframe.drop(['International',
                'Nationality', 
                "Father's qualification",
                'Curricular units 1st sem (credited)',
                'Curricular units 1st sem (enrolled)',
                'Curricular units 1st sem (approved)','Course',
                'Educational special needs','Unemployment rate',
                'Inflation rate'],axis=1,inplace=True)

# %%
dataframe.head()
# Out:
#    Marital status  Application mode  Application order  \
# 0               1                 8                  5
# 1               1                 6                  1
# 2               1                 1                  5
# 3               1                 8                  2
# 4               2                12                  1
#
#    Daytime/evening attendance  Previous qualification  Mother's qualification  \
# 0                           1                       1                      13
# 1                           1                       1                       1
# 2                           1                       1                      22
# 3                           1                       1                      23
# 4                           0                       1                      22
#
#    Mother's occupation  Father's occupation  Displaced  Debtor  ...  \
# 0                    6                   10          1       0  ...
# 1                    4                    4          1       0  ...
# 2                   10                   10          1       0  ...
# 3                    6                    4          1       0  ...
# 4                   10                   10          0       0  ...
#
#    Curricular units 1st sem (grade)  \
# 0                          0.000000
# 1                         14.000000
# 2                          0.000000
# 3                         13.428571
# 4                         12.333333
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    6
# 4                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)   GDP  Target
# 0                                               0  1.74       0
# 1                                               0  0.79       1
# 2                                               0  1.74       0
# 3                                               0 -3.12       1
# 4                                               0  0.79       1
#
# [5 rows x 25 columns]

# %%
dataframe.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order',
#        'Daytime/evening attendance', 'Previous qualification',
#        'Mother's qualification', 'Mother's occupation', 'Father's occupation',
#        'Displaced', 'Debtor', 'Tuition fees up to date', 'Gender',
#        'Scholarship holder', 'Age at enrollment',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'GDP', 'Target'],
#       dtype='object')

# %%
corr_matrix = dataframe.corr()

# %%
corr_matrix
# Out:
#                                                 Marital status  \
# Marital status                                        1.000000
# Application mode                                      0.235554
# Application order                                    -0.130370
# Daytime/evening attendance                           -0.265823
# Previous qualification                                0.134920
# Mother's qualification                                0.177000
# Mother's occupation                                   0.070876
# Father's occupation                                   0.029487
# Displaced                                            -0.240544
# Debtor                                                0.039470
# Tuition fees up to date                              -0.096920
# Gender                                               -0.001124
# Scholarship holder                                   -0.069684
# Age at enrollment                                     0.522359
# Curricular units 1st sem (evaluations)                0.059191
# Curricular units 1st sem (grade)                     -0.069442
# Curricular units 1st sem (without evaluations)        0.041535
# Curricular units 2nd sem (credited)                   0.067508
# Curricular units 2nd sem (enrolled)                   0.041256
# Curricular units 2nd sem (evaluations)                0.030786
# Curricular units 2nd sem (approved)                  -0.058400
# Curricular units 2nd sem (grade)                     -0.079536
# Curricular units 2nd sem (without evaluations)        0.025193
# GDP                                                  -0.028391
# Target                                               -0.100479
#
#                                                 Application mode  \
# Marital status                                          0.235554
# Application mode                                        1.000000
# Application order                                      -0.246369
# Daytime/evening attendance                             -0.276859
# Previous qualification                                  0.429339
# Mother's qualification                                  0.096560
# Mother's occupation                                     0.014639
# Father's occupation                                    -0.014781
# Displaced                                              -0.270626
# Debtor                                                  0.111712
# Tuition fees up to date                                -0.142187
# Gender                                                  0.170454
# Scholarship holder                                     -0.163377
# Age at enrollment                                       0.465425
# Curricular units 1st sem (evaluations)                  0.214080
# Curricular units 1st sem (grade)                       -0.120509
# Curricular units 1st sem (without evaluations)          0.045942
# Curricular units 2nd sem (credited)                     0.235376
# Curricular units 2nd sem (enrolled)                     0.129428
# Curricular units 2nd sem (evaluations)                  0.160493
# Curricular units 2nd sem (approved)                    -0.076839
# Curricular units 2nd sem (grade)                       -0.124287
# Curricular units 2nd sem (without evaluations)          0.052751
# GDP                                                    -0.014998
# Target                                                 -0.233888
#
#                                                 Application order  \
# Marital status                                          -0.130370
# Application mode                                        -0.246369
# Application order                                        1.000000
# Daytime/evening attendance                               0.165494
# Previous qualification                                  -0.204205
# Mother's qualification                                  -0.055105
# Mother's occupation                                     -0.036993
# Father's occupation                                     -0.027257
# Displaced                                                0.345791
# Debtor                                                  -0.066227
# Tuition fees up to date                                  0.061610
# Gender                                                  -0.106059
# Scholarship holder                                       0.072899
# Age at enrollment                                       -0.281641
# Curricular units 1st sem (evaluations)                  -0.086004
# Curricular units 1st sem (grade)                         0.060776
# Curricular units 1st sem (without evaluations)          -0.038958
# Curricular units 2nd sem (credited)                     -0.127599
# Curricular units 2nd sem (enrolled)                      0.033125
# Curricular units 2nd sem (evaluations)                  -0.042519
# Curricular units 2nd sem (approved)                      0.072595
# Curricular units 2nd sem (grade)                         0.059817
# Curricular units 2nd sem (without evaluations)          -0.026822
# GDP                                                      0.033031
# Target                                                   0.094355
#
#                                                 Daytime/evening attendance  \
# Marital status                                                   -0.265823
# Application mode                                                 -0.276859
# Application order                                                 0.165494
# Daytime/evening attendance                                        1.000000
# Previous qualification                                           -0.120619
# Mother's qualification                                           -0.179286
# Mother's occupation                                              -0.035792
# Father's occupation                                              -0.002980
# Displaced                                                         0.243653
# Debtor                                                            0.003900
# Tuition fees up to date                                           0.052186
# Gender                                                           -0.030507
# Scholarship holder                                                0.110240
# Age at enrollment                                                -0.453741
# Curricular units 1st sem (evaluations)                           -0.048432
# Curricular units 1st sem (grade)                                  0.073270
# Curricular units 1st sem (without evaluations)                    0.039307
# Curricular units 2nd sem (credited)                              -0.105494
# Curricular units 2nd sem (enrolled)                               0.006915
# Curricular units 2nd sem (evaluations)                            0.009977
# Curricular units 2nd sem (approved)                               0.054211
# Curricular units 2nd sem (grade)                                  0.058371
# Curricular units 2nd sem (without evaluations)                   -0.010504
# GDP                                                               0.005007
# Target                                                            0.084496
#
#                                                 Previous qualification  \
# Marital status                                                0.134920
# Application mode                                              0.429339
# Application order                                            -0.204205
# Daytime/evening attendance                                   -0.120619
# Previous qualification                                        1.000000
# Mother's qualification                                        0.011777
# Mother's occupation                                           0.001426
# Father's occupation                                           0.010741
# Displaced                                                    -0.165781
# Debtor                                                        0.122667
# Tuition fees up to date                                      -0.095072
# Gender                                                        0.107378
# Scholarship holder                                           -0.090529
# Age at enrollment                                             0.268435
# Curricular units 1st sem (evaluations)                        0.126542
# Curricular units 1st sem (grade)                             -0.048686
# Curricular units 1st sem (without evaluations)                0.039461
# Curricular units 2nd sem (credited)                           0.139557
# Curricular units 2nd sem (enrolled)                           0.052077
# Curricular units 2nd sem (evaluations)                        0.084018
# Curricular units 2nd sem (approved)                          -0.046298
# Curricular units 2nd sem (grade)                             -0.051467
# Curricular units 2nd sem (without evaluations)                0.045677
# GDP                                                           0.058446
# Target                                                       -0.102795
#
#                                                 Mother's qualification  \
# Marital status                                                0.177000
# Application mode                                              0.096560
# Application order                                            -0.055105
# Daytime/evening attendance                                   -0.179286
# Previous qualification                                        0.011777
# Mother's qualification                                        1.000000
# Mother's occupation                                           0.309000
# Father's occupation                                           0.134823
# Displaced                                                    -0.071407
# Debtor                                                        0.011009
# Tuition fees up to date                                      -0.027624
# Gender                                                       -0.046287
# Scholarship holder                                            0.029713
# Age at enrollment                                             0.277025
# Curricular units 1st sem (evaluations)                        0.046130
# Curricular units 1st sem (grade)                             -0.041897
# Curricular units 1st sem (without evaluations)                0.013946
# Curricular units 2nd sem (credited)                           0.035655
# Curricular units 2nd sem (enrolled)                           0.030811
# Curricular units 2nd sem (evaluations)                        0.030954
# Curricular units 2nd sem (approved)                          -0.024289
# Curricular units 2nd sem (grade)                             -0.031406
# Curricular units 2nd sem (without evaluations)                0.027816
# GDP                                                          -0.071692
# Target                                                       -0.048459
#
#                                                 Mother's occupation  \
# Marital status                                             0.070876
# Application mode                                           0.014639
# Application order                                         -0.036993
# Daytime/evening attendance                                -0.035792
# Previous qualification                                     0.001426
# Mother's qualification                                     0.309000
# Mother's occupation                                        1.000000
# Father's occupation                                        0.693807
# Displaced                                                 -0.042925
# Debtor                                                     0.093864
# Tuition fees up to date                                   -0.017352
# Gender                                                    -0.034881
# Scholarship holder                                         0.121071
# Age at enrollment                                          0.078605
# Curricular units 1st sem (evaluations)                    -0.005374
# Curricular units 1st sem (grade)                           0.014713
# Curricular units 1st sem (without evaluations)            -0.013753
# Curricular units 2nd sem (credited)                       -0.003886
# Curricular units 2nd sem (enrolled)                        0.001080
# Curricular units 2nd sem (evaluations)                    -0.006691
# Curricular units 2nd sem (approved)                        0.030936
# Curricular units 2nd sem (grade)                           0.041212
# Curricular units 2nd sem (without evaluations)            -0.001678
# GDP                                                        0.070732
# Target                                                     0.064195
#
#                                                 Father's occupation  \
# Marital status                                             0.029487
# Application mode                                          -0.014781
# Application order                                         -0.027257
# Daytime/evening attendance                                -0.002980
# Previous qualification                                     0.010741
# Mother's qualification                                     0.134823
# Mother's occupation                                        0.693807
# Father's occupation                                        1.000000
# Displaced                                                 -0.035894
# Debtor                                                     0.082943
# Tuition fees up to date                                    0.011994
# Gender                                                    -0.045968
# Scholarship holder                                         0.101472
# Age at enrollment                                         -0.004065
# Curricular units 1st sem (evaluations)                    -0.027839
# Curricular units 1st sem (grade)                           0.024759
# Curricular units 1st sem (without evaluations)            -0.037168
# Curricular units 2nd sem (credited)                       -0.017998
# Curricular units 2nd sem (enrolled)                       -0.009356
# Curricular units 2nd sem (evaluations)                    -0.028205
# Curricular units 2nd sem (approved)                        0.032742
# Curricular units 2nd sem (grade)                           0.041246
# Curricular units 2nd sem (without evaluations)            -0.047528
# GDP                                                        0.098918
# Target                                                     0.073238
#
#                                                 Displaced    Debtor  ...  \
# Marital status                                  -0.240544  0.039470  ...
# Application mode                                -0.270626  0.111712  ...
# Application order                                0.345791 -0.066227  ...
# Daytime/evening attendance                       0.243653  0.003900  ...
# Previous qualification                          -0.165781  0.122667  ...
# Mother's qualification                          -0.071407  0.011009  ...
# Mother's occupation                             -0.042925  0.093864  ...
# Father's occupation                             -0.035894  0.082943  ...
# Displaced                                        1.000000 -0.093718  ...
# Debtor                                          -0.093718  1.000000  ...
# Tuition fees up to date                          0.105403 -0.434906  ...
# Gender                                          -0.127896  0.052770  ...
# Scholarship holder                               0.086337 -0.065204  ...
# Age at enrollment                               -0.370018  0.104142  ...
# Curricular units 1st sem (evaluations)          -0.075391  0.029886  ...
# Curricular units 1st sem (grade)                 0.077809 -0.110522  ...
# Curricular units 1st sem (without evaluations)  -0.031757  0.013740  ...
# Curricular units 2nd sem (credited)             -0.096240  0.007597  ...
# Curricular units 2nd sem (enrolled)             -0.046431 -0.050772  ...
# Curricular units 2nd sem (evaluations)          -0.035874  0.014412  ...
# Curricular units 2nd sem (approved)              0.076466 -0.166305  ...
# Curricular units 2nd sem (grade)                 0.084463 -0.146603  ...
# Curricular units 2nd sem (without evaluations)  -0.041696  0.069970  ...
# GDP                                              0.064923  0.040475  ...
# Target                                           0.126113 -0.267207  ...
#
#                                                 Curricular units 1st sem (grade)  \
# Marital status                                                         -0.069442
# Application mode                                                       -0.120509
# Application order                                                       0.060776
# Daytime/evening attendance                                              0.073270
# Previous qualification                                                 -0.048686
# Mother's qualification                                                 -0.041897
# Mother's occupation                                                     0.014713
# Father's occupation                                                     0.024759
# Displaced                                                               0.077809
# Debtor                                                                 -0.110522
# Tuition fees up to date                                                 0.275555
# Gender                                                                 -0.207082
# Scholarship holder                                                      0.196180
# Age at enrollment                                                      -0.180723
# Curricular units 1st sem (evaluations)                                  0.425039
# Curricular units 1st sem (grade)                                        1.000000
# Curricular units 1st sem (without evaluations)                         -0.064171
# Curricular units 2nd sem (credited)                                     0.120199
# Curricular units 2nd sem (enrolled)                                     0.407084
# Curricular units 2nd sem (evaluations)                                  0.503365
# Curricular units 2nd sem (approved)                                     0.691907
# Curricular units 2nd sem (grade)                                        0.845864
# Curricular units 2nd sem (without evaluations)                         -0.055861
# GDP                                                                     0.054168
# Target                                                                  0.519927
#
#                                                 Curricular units 1st sem (without evaluations)  \
# Marital status                                                                        0.041535
# Application mode                                                                      0.045942
# Application order                                                                    -0.038958
# Daytime/evening attendance                                                            0.039307
# Previous qualification                                                                0.039461
# Mother's qualification                                                                0.013946
# Mother's occupation                                                                  -0.013753
# Father's occupation                                                                  -0.037168
# Displaced                                                                            -0.031757
# Debtor                                                                                0.013740
# Tuition fees up to date                                                              -0.069509
# Gender                                                                                0.006808
# Scholarship holder                                                                   -0.069637
# Age at enrollment                                                                     0.078435
# Curricular units 1st sem (evaluations)                                                0.267383
# Curricular units 1st sem (grade)                                                     -0.064171
# Curricular units 1st sem (without evaluations)                                        1.000000
# Curricular units 2nd sem (credited)                                                   0.144378
# Curricular units 2nd sem (enrolled)                                                   0.123588
# Curricular units 2nd sem (evaluations)                                                0.170004
# Curricular units 2nd sem (approved)                                                   0.001458
# Curricular units 2nd sem (grade)                                                     -0.068725
# Curricular units 2nd sem (without evaluations)                                        0.601573
# GDP                                                                                  -0.130766
# Target                                                                               -0.074642
#
#                                                 Curricular units 2nd sem (credited)  \
# Marital status                                                             0.067508
# Application mode                                                           0.235376
# Application order                                                         -0.127599
# Daytime/evening attendance                                                -0.105494
# Previous qualification                                                     0.139557
# Mother's qualification                                                     0.035655
# Mother's occupation                                                       -0.003886
# Father's occupation                                                       -0.017998
# Displaced                                                                 -0.096240
# Debtor                                                                     0.007597
# Tuition fees up to date                                                    0.020306
# Gender                                                                     0.023027
# Scholarship holder                                                        -0.079378
# Age at enrollment                                                          0.196485
# Curricular units 1st sem (evaluations)                                     0.546980
# Curricular units 1st sem (grade)                                           0.120199
# Curricular units 1st sem (without evaluations)                             0.144378
# Curricular units 2nd sem (credited)                                        1.000000
# Curricular units 2nd sem (enrolled)                                        0.683086
# Curricular units 2nd sem (evaluations)                                     0.453716
# Curricular units 2nd sem (approved)                                        0.522684
# Curricular units 2nd sem (grade)                                           0.140181
# Curricular units 2nd sem (without evaluations)                             0.084506
# GDP                                                                       -0.038570
# Target                                                                     0.052402
#
#                                                 Curricular units 2nd sem (enrolled)  \
# Marital status                                                             0.041256
# Application mode                                                           0.129428
# Application order                                                          0.033125
# Daytime/evening attendance                                                 0.006915
# Previous qualification                                                     0.052077
# Mother's qualification                                                     0.030811
# Mother's occupation                                                        0.001080
# Father's occupation                                                       -0.009356
# Displaced                                                                 -0.046431
# Debtor                                                                    -0.050772
# Tuition fees up to date                                                    0.103347
# Gender                                                                    -0.126659
# Scholarship holder                                                         0.024982
# Age at enrollment                                                          0.071177
# Curricular units 1st sem (evaluations)                                     0.625967
# Curricular units 1st sem (grade)                                           0.407084
# Curricular units 1st sem (without evaluations)                             0.123588
# Curricular units 2nd sem (credited)                                        0.683086
# Curricular units 2nd sem (enrolled)                                        1.000000
# Curricular units 2nd sem (evaluations)                                     0.625080
# Curricular units 2nd sem (approved)                                        0.704445
# Curricular units 2nd sem (grade)                                           0.400773
# Curricular units 2nd sem (without evaluations)                             0.070363
# GDP                                                                       -0.026076
# Target                                                                     0.182897
#
#                                                 Curricular units 2nd sem (evaluations)  \
# Marital status                                                                0.030786
# Application mode                                                              0.160493
# Application order                                                            -0.042519
# Daytime/evening attendance                                                    0.009977
# Previous qualification                                                        0.084018
# Mother's qualification                                                        0.030954
# Mother's occupation                                                          -0.006691
# Father's occupation                                                          -0.028205
# Displaced                                                                    -0.035874
# Debtor                                                                        0.014412
# Tuition fees up to date                                                       0.055691
# Gender                                                                       -0.048000
# Scholarship holder                                                            0.005903
# Age at enrollment                                                             0.059554
# Curricular units 1st sem (evaluations)                                        0.790616
# Curricular units 1st sem (grade)                                              0.503365
# Curricular units 1st sem (without evaluations)                                0.170004
# Curricular units 2nd sem (credited)                                           0.453716
# Curricular units 2nd sem (enrolled)                                           0.625080
# Curricular units 2nd sem (evaluations)                                        1.000000
# Curricular units 2nd sem (approved)                                           0.508968
# Curricular units 2nd sem (grade)                                              0.463194
# Curricular units 2nd sem (without evaluations)                                0.166443
# GDP                                                                          -0.021846
# Target                                                                        0.119239
#
#                                                 Curricular units 2nd sem (approved)  \
# Marital status                                                            -0.058400
# Application mode                                                          -0.076839
# Application order                                                          0.072595
# Daytime/evening attendance                                                 0.054211
# Previous qualification                                                    -0.046298
# Mother's qualification                                                    -0.024289
# Mother's occupation                                                        0.030936
# Father's occupation                                                        0.032742
# Displaced                                                                  0.076466
# Debtor                                                                    -0.166305
# Tuition fees up to date                                                    0.329017
# Gender                                                                    -0.234663
# Scholarship holder                                                         0.214997
# Age at enrollment                                                         -0.147668
# Curricular units 1st sem (evaluations)                                     0.466744
# Curricular units 1st sem (grade)                                           0.691907
# Curricular units 1st sem (without evaluations)                             0.001458
# Curricular units 2nd sem (credited)                                        0.522684
# Curricular units 2nd sem (enrolled)                                        0.704445
# Curricular units 2nd sem (evaluations)                                     0.508968
# Curricular units 2nd sem (approved)                                        1.000000
# Curricular units 2nd sem (grade)                                           0.786838
# Curricular units 2nd sem (without evaluations)                            -0.052389
# GDP                                                                        0.014514
# Target                                                                     0.653995
#
#                                                 Curricular units 2nd sem (grade)  \
# Marital status                                                         -0.079536
# Application mode                                                       -0.124287
# Application order                                                       0.059817
# Daytime/evening attendance                                              0.058371
# Previous qualification                                                 -0.051467
# Mother's qualification                                                 -0.031406
# Mother's occupation                                                     0.041212
# Father's occupation                                                     0.041246
# Displaced                                                               0.084463
# Debtor                                                                 -0.146603
# Tuition fees up to date                                                 0.318721
# Gender                                                                 -0.219696
# Scholarship holder                                                      0.212342
# Age at enrollment                                                      -0.194145
# Curricular units 1st sem (evaluations)                                  0.353550
# Curricular units 1st sem (grade)                                        0.845864
# Curricular units 1st sem (without evaluations)                         -0.068725
# Curricular units 2nd sem (credited)                                     0.140181
# Curricular units 2nd sem (enrolled)                                     0.400773
# Curricular units 2nd sem (evaluations)                                  0.463194
# Curricular units 2nd sem (approved)                                     0.786838
# Curricular units 2nd sem (grade)                                        1.000000
# Curricular units 2nd sem (without evaluations)                         -0.079508
# GDP                                                                     0.066077
# Target                                                                  0.605350
#
#                                                 Curricular units 2nd sem (without evaluations)  \
# Marital status                                                                        0.025193
# Application mode                                                                      0.052751
# Application order                                                                    -0.026822
# Daytime/evening attendance                                                           -0.010504
# Previous qualification                                                                0.045677
# Mother's qualification                                                                0.027816
# Mother's occupation                                                                  -0.001678
# Father's occupation                                                                  -0.047528
# Displaced                                                                            -0.041696
# Debtor                                                                                0.069970
# Tuition fees up to date                                                              -0.095139
# Gender                                                                                0.057755
# Scholarship holder                                                                   -0.060597
# Age at enrollment                                                                     0.080135
# Curricular units 1st sem (evaluations)                                                0.158399
# Curricular units 1st sem (grade)                                                     -0.055861
# Curricular units 1st sem (without evaluations)                                        0.601573
# Curricular units 2nd sem (credited)                                                   0.084506
# Curricular units 2nd sem (enrolled)                                                   0.070363
# Curricular units 2nd sem (evaluations)                                                0.166443
# Curricular units 2nd sem (approved)                                                  -0.052389
# Curricular units 2nd sem (grade)                                                     -0.079508
# Curricular units 2nd sem (without evaluations)                                        1.000000
# GDP                                                                                  -0.079857
# Target                                                                               -0.102687
#
#                                                      GDP    Target
# Marital status                                 -0.028391 -0.100479
# Application mode                               -0.014998 -0.233888
# Application order                               0.033031  0.094355
# Daytime/evening attendance                      0.005007  0.084496
# Previous qualification                          0.058446 -0.102795
# Mother's qualification                         -0.071692 -0.048459
# Mother's occupation                             0.070732  0.064195
# Father's occupation                             0.098918  0.073238
# Displaced                                       0.064923  0.126113
# Debtor                                          0.040475 -0.267207
# Tuition fees up to date                         0.027771  0.442138
# Gender                                         -0.021931 -0.251955
# Scholarship holder                              0.037842  0.313018
# Age at enrollment                              -0.069184 -0.267229
# Curricular units 1st sem (evaluations)         -0.111698  0.059786
# Curricular units 1st sem (grade)                0.054168  0.519927
# Curricular units 1st sem (without evaluations) -0.130766 -0.074642
# Curricular units 2nd sem (credited)            -0.038570  0.052402
# Curricular units 2nd sem (enrolled)            -0.026076  0.182897
# Curricular units 2nd sem (evaluations)         -0.021846  0.119239
# Curricular units 2nd sem (approved)             0.014514  0.653995
# Curricular units 2nd sem (grade)                0.066077  0.605350
# Curricular units 2nd sem (without evaluations) -0.079857 -0.102687
# GDP                                             1.000000  0.050260
# Target                                          0.050260  1.000000
#
# [25 rows x 25 columns]

# %%
plt.figure(figsize = (25, 25))
sns.heatmap(corr_matrix, 
            annot = True, 
            cmap = 'inferno')
# Out:
# <Axes: >

# %%
pd.crosstab(dataframe.Target, dataframe.Gender).plot(kind='bar',color=['salmon', 'lightblue'])
plt.title("Student status based on gender")
plt.ylabel("students")
plt.legend(["Female", "Male"])
plt.xticks(rotation=0);

# %%
sns.lineplot(x="Course", y="Target", data=dataframe)
plt.show()

# %%
dataframe.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order',
#        'Daytime/evening attendance', 'Previous qualification',
#        'Mother's qualification', 'Mother's occupation', 'Father's occupation',
#        'Displaced', 'Debtor', 'Tuition fees up to date', 'Gender',
#        'Scholarship holder', 'Age at enrollment',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'GDP', 'Target'],
#       dtype='object')

# %% [markdown]
# # Correlation Of Graduation Rate :

# %%
dataset = dataframe.drop('Target', axis = 1)

# %%
dataset.head()
# Out:
#    Marital status  Application mode  Application order  \
# 0               1                 8                  5
# 1               1                 6                  1
# 2               1                 1                  5
# 3               1                 8                  2
# 4               2                12                  1
#
#    Daytime/evening attendance  Previous qualification  Mother's qualification  \
# 0                           1                       1                      13
# 1                           1                       1                       1
# 2                           1                       1                      22
# 3                           1                       1                      23
# 4                           0                       1                      22
#
#    Mother's occupation  Father's occupation  Displaced  Debtor  ...  \
# 0                    6                   10          1       0  ...
# 1                    4                    4          1       0  ...
# 2                   10                   10          1       0  ...
# 3                    6                    4          1       0  ...
# 4                   10                   10          0       0  ...
#
#    Curricular units 1st sem (evaluations)  Curricular units 1st sem (grade)  \
# 0                                       0                          0.000000
# 1                                       6                         14.000000
# 2                                       0                          0.000000
# 3                                       8                         13.428571
# 4                                       9                         12.333333
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    6
# 4                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)   GDP
# 0                                               0  1.74
# 1                                               0  0.79
# 2                                               0  1.74
# 3                                               0 -3.12
# 4                                               0  0.79
#
# [5 rows x 24 columns]

# %%
dataset.corrwith(dataframe['Target']).plot.bar(
    title = 'Correlation With Dropout', 
    figsize = (12, 5) , 
    cmap = 'plasma'
)
# Out:
# <Axes: title={'center': 'Correlation With Dropout'}>

# %%
dataframe.head()
# Out:
#    Marital status  Application mode  Application order  \
# 0               1                 8                  5
# 1               1                 6                  1
# 2               1                 1                  5
# 3               1                 8                  2
# 4               2                12                  1
#
#    Daytime/evening attendance  Previous qualification  Mother's qualification  \
# 0                           1                       1                      13
# 1                           1                       1                       1
# 2                           1                       1                      22
# 3                           1                       1                      23
# 4                           0                       1                      22
#
#    Mother's occupation  Father's occupation  Displaced  Debtor  ...  \
# 0                    6                   10          1       0  ...
# 1                    4                    4          1       0  ...
# 2                   10                   10          1       0  ...
# 3                    6                    4          1       0  ...
# 4                   10                   10          0       0  ...
#
#    Curricular units 1st sem (grade)  \
# 0                          0.000000
# 1                         14.000000
# 2                          0.000000
# 3                         13.428571
# 4                         12.333333
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    6
# 4                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)   GDP  Target
# 0                                               0  1.74       0
# 1                                               0  0.79       1
# 2                                               0  1.74       0
# 3                                               0 -3.12       1
# 4                                               0  0.79       1
#
# [5 rows x 25 columns]

# %% [markdown]
# # Splitting Dataset :

# %% [markdown]
# Splitting a dataset refers to the process of dividing a given dataset into two or more subsets for training and evaluation purposes. The most common type of split is between the training set and the testing (or validation) set. This division allows us to assess the performance of a machine learning model on unseen data and evaluate its generalization capabilities.
#
# Train-Test Split: This is the most basic type of split, where the dataset is divided into a training set and a testing set. The training set is used to train the machine learning model, while the testing set is used to evaluate its performance. The split is typically done using a fixed ratio, such as 80% for training and 20% for testing.

# %%
x = dataframe.drop('Target', axis = 1)
y = dataframe['Target']

# %%
x.shape, y.shape
# Out:
# ((3630, 24), (3630,))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,  
                                                    y, 
                                                    test_size = 0.3, 
                                                    stratify = y, 
                                                    random_state = 42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((2541, 24), (1089, 24), (2541,), (1089,))

# %% [markdown]
# # Scaling :

# %% [markdown]
# Scaling is a preprocessing technique used in machine learning to transform the input features to a similar scale. It is often necessary because features can have different units, ranges, or magnitudes, which can affect the performance of certain algorithms. Scaling ensures that all features contribute equally to the learning process and prevents features with larger values from dominating those with smaller values.
#
# StandardScaler is a commonly used method for scaling numerical features in machine learning. It is part of the preprocessing module in scikit-learn, a popular machine learning library in Python.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-0.3002885 , -1.09973036, -0.56574082, ...,  0.54376269,
#         -0.18874023,  0.79649683],
#        [-0.3002885 ,  0.0459129 ,  0.18220269, ...,  0.39318043,
#         -0.18874023,  0.77418582],
#        [-0.3002885 ,  0.0459129 ,  0.18220269, ...,  0.39318043,
#         -0.18874023, -1.39444413],
#        ...,
#        [-0.3002885 , -0.52690873, -0.56574082, ..., -1.80532043,
#         -0.18874023,  0.35027667],
#        [-0.3002885 , -1.09973036, -0.56574082, ...,  0.64917026,
#         -0.18874023,  1.56399549],
#        [ 1.37670726,  1.00061561, -0.56574082, ..., -1.80532043,
#         -0.18874023, -0.41275979]])

# %%
x_test
# Out:
# array([[-0.3002885 , -1.09973036,  0.18220269, ...,  0.31272649,
#         -0.18874023, -0.76081151],
#        [-0.3002885 ,  0.23685344, -0.56574082, ...,  0.18236528,
#         -0.18874023,  0.35027667],
#        [-0.3002885 ,  1.57343724, -0.56574082, ...,  0.15655118,
#         -0.18874023, -1.81389107],
#        ...,
#        [-0.3002885 , -1.09973036,  0.18220269, ...,  0.430826  ,
#         -0.18874023,  0.35027667],
#        [-0.3002885 ,  0.23685344, -0.56574082, ...,  0.18236528,
#         -0.18874023,  0.1405532 ],
#        [-0.3002885 ,  0.23685344,  0.18220269, ...,  0.42329688,
#         -0.18874023,  0.35027667]])

# %% [markdown]
# # Model Selection And Training :

# %% [markdown]
# Model Selection:
#
# Model selection involves choosing the best algorithm or model architecture for the given problem and dataset. This step requires careful consideration of various factors, such as the nature of the data (e.g., numerical or categorical), the problem type (e.g., regression, classification, clustering), the amount of available data, and the desired model performance. It is essential to select a model that can effectively capture the underlying patterns in the data and make accurate predictions.

# %% [markdown]
# Model Training:
#
# Once the appropriate model has been selected, the next step is to train it on the dataset. Model training involves adjusting the model's parameters using the training data to make accurate predictions on unseen data. The goal is to minimize the difference between the model's predictions and the actual target values during training.

# %%
x_train.shape, x_test.shape
# Out:
# ((2541, 24), (1089, 24))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier()

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
clf.score(x_test, y_test)
# Out:
# 0.9035812672176309

# %% [markdown]
# # Hyper-parameter Tuning :

# %% [markdown]
# Hyperparameter tuning is a critical process in machine learning that involves finding the optimal set of hyperparameters for a given model. Hyperparameters are configuration settings that are not learned from the data during model training but are set before the training process begins. They significantly impact the model's performance and generalization ability.
#
# The goal of hyperparameter tuning is to systematically search through different combinations of hyperparameters to identify the configuration that yields the best model performance. The process ensures that the model is well-optimized and capable of making accurate predictions on new, unseen data.

# %% [markdown]
# Grid Search:
#
# Grid search involves specifying a list of values for each hyperparameter. The algorithm then exhaustively tries all possible combinations of hyperparameters to find the best one. This method is simple and can be effective for a small number of hyperparameters, but it becomes computationally expensive as the number of hyperparameters increases.

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [None , 10, 20],
    'min_samples_split': [2,4,5],
    'min_samples_leaf': [1,2,4],
}

# %%
clf_grid=GridSearchCV(estimator=clf, 
                     param_grid=param_grid,
                     cv=3,
                     verbose=0,
                     n_jobs=-1,
                     return_train_score=False)

# %%
clf_grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 4, 5],
#                          'n_estimators': [50, 100]})

# %%
clf_grid.best_params_
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 50}

# %%
random_forest = RandomForestClassifier(**clf_grid.best_params_)

# %%
random_forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=50)

# %% [markdown]
# # Prediction On x-Test :

# %%
y_pred = random_forest.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
print(y_test.iloc[20]), print(y_pred[20])
# Out:
# 1
# 1
# (None, None)

# %%
print(y_test.iloc[30]), print(y_pred[30])
# Out:
# 0
# 0
# (None, None)

# %% [markdown]
# # Error Analysis :

# %% [markdown]
# Error analysis is a crucial process in machine learning and data analysis, aiming to understand model errors and patterns of misclassifications. By investigating causes and impacts of errors, analysts can devise strategies to improve the model's performance, leading to more accurate and reliable predictions. This iterative process enables continuous refinement, making machine learning systems more effective in real-world applications.

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, recall_score, precision_score

# %%
accuracy_score = accuracy_score(y_test, y_pred)
print('Accuracy_score: ', accuracy_score)
# Out:
# Accuracy_score:  0.9044995408631772

# %%
precision_score = precision_score(y_test, y_pred)
print('Precision_score: ', precision_score)
# Out:
# Precision_score:  0.8887343532684284

# %%
f1_score = f1_score(y_test, y_pred)
print('f1_score: ', f1_score)
# Out:
# f1_score:  0.9247467438494935

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87       426
#            1       0.89      0.96      0.92       663
#
#     accuracy                           0.90      1089
#    macro avg       0.91      0.89      0.90      1089
# weighted avg       0.91      0.90      0.90      1089

# %%
confusion_matrix = confusion_matrix(y_test, y_pred)

# %%
confusion_matrix
# Out:
# array([[346,  80],
#        [ 24, 639]], dtype=int64)

# %%
plt.figure(figsize = (6, 4))
sns.heatmap(confusion_matrix, 
            annot = True, 
            cmap = 'RdPu')
# Out:
# <Axes: >

# %% [markdown]
# # Conclusion :

# %% [markdown]
# We can say that,predicting student success rate using data-driven models enables timely interventions and personalized support. This empowers educators to proactively assist students facing challenges, fostering a more equitable and successful learning environment while maintaining ethical considerations.

# %% [markdown]
# # Thanks !

# %% [markdown]
# Thanks And Upvote If you Like it !!!
